# %%
import numpy as np #numerical computation
import pandas as pd #data wrangling
import matplotlib.pyplot as plt #plotting package
#Next line helps with rendering plots
# %matplotlib inline
import matplotlib as mpl #add'l plotting functionality
import seaborn as sns #a fancy plotting package
mpl.rcParams['figure.dpi'] = 400 #high res figures

# %% [markdown]
# Load data

# %%
df = pd.read_csv('../../../Data/Chapter_1_cleaned_data.csv')

# %% [markdown]
# # 1. Examining the relationships between features and response

# %%
features_response = df.columns.tolist()

# %%
features_response[:5]
# Out:
# ['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE']

# %%
features_response[-5:]
# Out:
# ['graduate school', 'high school', 'none', 'others', 'university']

# %%
items_to_remove = ['ID', 'SEX', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6',
                   'EDUCATION_CAT', 'graduate school', 'high school', 'none',
                   'others', 'university']

# %%
example_list_comp = [item for item in range(5)]
example_list_comp
# Out:
# [0, 1, 2, 3, 4]

# %%
features_response = [item for item in features_response if item not in items_to_remove]
features_response
# Out:
# ['LIMIT_BAL',
#  'EDUCATION',
#  'MARRIAGE',
#  'AGE',
#  'PAY_1',
#  'BILL_AMT1',
#  'BILL_AMT2',
#  'BILL_AMT3',
#  'BILL_AMT4',
#  'BILL_AMT5',
#  'BILL_AMT6',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_AMT3',
#  'PAY_AMT4',
#  'PAY_AMT5',
#  'PAY_AMT6',
#  'default payment next month']

# %%
corr = df[features_response].corr()
corr.iloc[0:5,0:5]
# Out:
#            LIMIT_BAL  EDUCATION  MARRIAGE       AGE     PAY_1
# LIMIT_BAL   1.000000  -0.232688 -0.111873  0.149157 -0.273396
# EDUCATION  -0.232688   1.000000 -0.137097  0.179035  0.112653
# MARRIAGE   -0.111873  -0.137097  1.000000 -0.412828  0.019759
# AGE         0.149157   0.179035 -0.412828  1.000000 -0.044277
# PAY_1      -0.273396   0.112653  0.019759 -0.044277  1.000000

# %%
mpl.rcParams['figure.dpi'] = 400 #high res figures
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
            center=0)

# %%
n_points = 500
np.random.seed(seed=2)
X = np.random.uniform(low=0.0, high=10.0, size=(n_points,))
slope = 0.25
noise = 0.2
y=[]
y.append( slope * X + np.random.normal(loc=0.0, scale=noise, size=(n_points,)))
y.append( -slope * X + np.random.normal(loc=0.0, scale=noise, size=(n_points,)))
y.append( np.random.normal(loc=0.0, scale=noise, size=(n_points,)))
y.append( np.sin(X/(2)*np.pi) + np.random.normal(loc=0.0, scale=noise, size=(n_points,)))

# %%
np.corrcoef(X, y[3])
# Out:
# array([[1.        , 0.01900706],
#        [0.01900706, 1.        ]])

# %%
mpl.rcParams['figure.dpi'] = 200
fig_h, ax_h = plt.subplots(2,2)
counter = 0
correlations = []
titles = ['A', 'B', 'C', 'D']
for axis in ax_h.flatten():
    axis.scatter(X,y[counter],s=0.5)
    axis.set_xticks([])
    axis.set_yticks([])
    axis.set_title(titles[counter])
#     axis.set_title( r'$\rho = ${:0.2f}'.format(np.corrcoef(X, y[counter])[0,1]))
    correlations.append(np.corrcoef(X, y[counter])[0,1])
    counter+=1

# %%
correlations
# Out:
# [0.9637513276497903,
#  -0.9659993956705684,
#  0.06339625904219301,
#  0.019007055545229253]

# %%
# df_sample = df[['LIMIT_BAL', 'PAY_1', 'default payment next month']]\
# .sample(frac=0.1, replace=False, random_state=1, axis=0)

#Hard to see much value in either of these:
# sns.pairplot(df_sample, hue='default payment next month')
# pd.scatter_matrix(df_sample)

# %% [markdown]
# # Exercise 1: F-test and univariate feature selection

# %%
X = df[features_response].iloc[:,:-1].values
y = df[features_response].iloc[:,-1].values
print(X.shape, y.shape)
# Out:
# (26664, 17) (26664,)

# %%
from sklearn.feature_selection import f_classif

# %%
[f_stat, f_p_value] = f_classif(X, y)

# %%
f_test_df = pd.DataFrame({'Feature':features_response[:-1],
                          'F statistic':f_stat,
                          'p value':f_p_value})
f_test_df.sort_values('p value')
# Out:
#       Feature  F statistic        p value
# 4       PAY_1  3156.672300   0.000000e+00
# 0   LIMIT_BAL   651.324071  5.838366e-142
# 11   PAY_AMT1   140.612679   2.358354e-32
# 12   PAY_AMT2   101.408321   8.256124e-24
# 13   PAY_AMT3    90.023873   2.542641e-21
# 15   PAY_AMT5    85.843295   2.090120e-20
# 16   PAY_AMT6    80.420784   3.219565e-19
# 14   PAY_AMT4    79.640021   4.774112e-19
# 1   EDUCATION    32.637768   1.122175e-08
# 2    MARRIAGE    18.078027   2.127555e-05
# 5   BILL_AMT1    11.218406   8.110226e-04
# 7   BILL_AMT3     5.722938   1.675157e-02
# 6   BILL_AMT2     5.668454   1.727965e-02
# 3         AGE     5.479140   1.925206e-02
# 8   BILL_AMT4     3.434740   6.384965e-02
# 9   BILL_AMT5     1.216082   2.701409e-01
# 10  BILL_AMT6     1.049561   3.056176e-01

# %%
from sklearn.feature_selection import SelectPercentile

# %%
selector = SelectPercentile(f_classif, percentile=20)

# %%
selector.fit(X, y)
# Out:
# SelectPercentile(percentile=20,
#          score_func=<function f_classif at 0x1a1a829510>)

# %%
best_feature_ix = selector.get_support()
best_feature_ix
# Out:
# array([ True, False, False, False,  True, False, False, False, False,
#        False, False,  True,  True, False, False, False, False])

# %%
features = features_response[:-1]

# %%
best_features = [features[counter] for counter in range(len(features))
                 if best_feature_ix[counter]]

# %%
best_features
# Out:
# ['LIMIT_BAL', 'PAY_1', 'PAY_AMT1', 'PAY_AMT2']

# %% [markdown]
# # Exercise 2: Examine important features, develop hypotheses

# %%
group_by_pay_mean_y = df.groupby('PAY_1').agg({'default payment next month':np.mean})
group_by_pay_mean_y
# Out:
#        default payment next month
# PAY_1
# -2                       0.131664
# -1                       0.170002
#  0                       0.128295
#  1                       0.336400
#  2                       0.694701
#  3                       0.773973
#  4                       0.682540
#  5                       0.434783
#  6                       0.545455
#  7                       0.777778
#  8                       0.588235

# %%
overall_default_rate = df['default payment next month'].mean()
overall_default_rate
# Out:
# 0.2217971797179718

# %%
axes = plt.axes()
axes.axhline(overall_default_rate, color='red')
group_by_pay_mean_y.plot(marker='x', legend=False, ax=axes)
axes.set_ylabel('Proportion of credit defaults')
axes.legend(['Entire data set', 'Groups of PAY_1'])

# %%
pos_mask = y == 1
neg_mask = y == 0

# %%
axes = plt.axes()
axes.hist(df.loc[neg_mask, 'LIMIT_BAL'], alpha=0.5, color='blue')
axes.hist(df.loc[pos_mask, 'LIMIT_BAL'], alpha=0.5, color='red')
axes.tick_params(axis='x', labelrotation=45)
axes.set_xlabel('Credit limit (NT$)')
axes.set_ylabel('Number of accounts')
axes.legend(['Not defaulted', 'Defaulted'])
axes.set_title('Credit limits by response variable')
# Out:
# Text(0.5, 1.0, 'Credit limits by response variable')

# %%
df['LIMIT_BAL'].max()
# Out:
# 800000

# %%
bin_edges = list(range(0,850000,50000))
print(bin_edges[-1])
# Out:
# 800000

# %%
mpl.rcParams['figure.dpi'] = 400 
axes = plt.axes()
axes.hist(df.loc[neg_mask, 'LIMIT_BAL'], bins=bin_edges, alpha=0.5, density=True, color='blue')
axes.hist(df.loc[pos_mask, 'LIMIT_BAL'], bins=bin_edges, alpha=0.5, density=True, color='red')
axes.tick_params(axis='x', labelrotation=45)
axes.set_xlabel('Credit limit (NT$)')
axes.set_ylabel('Proportion of accounts')
y_ticks = axes.get_yticks()
axes.set_yticklabels(np.round(y_ticks*50000,2))
axes.legend(['Not defaulted', 'Defaulted'])
axes.set_title('Normalized distribution of credit limits by response variable')
# Out:
# Text(0.5, 1.0, 'Normalized distribution of credit limits by response variable')

# %% [markdown]
# # The sigmoid equation

# %% [markdown]
# Make a function out of it, which introduces the concept of function

# %% [markdown]
# # Linear decision boundary of logistic regression

# %%
np.random.seed(seed=6)
X_1_pos = np.random.uniform(low=1, high=7, size=(20,1))
print(X_pos[0:5])
X_1_neg = np.random.uniform(low=3, high=10, size=(20,1))
print(X_neg[0:5])
X_2_pos = np.random.uniform(low=1, high=7, size=(20,1))
print(y_pos[0:5])
X_2_neg = np.random.uniform(low=3, high=10, size=(20,1))
print(y_neg[0:5])
# Out:
# [3.50213203 5.32194696 1.00068625 2.81399544 1.88053534]
# [8.60521198 9.77783103 5.19396925 7.84625831 9.13472407]
# [6.93316653 5.48899393 2.68266395 5.73567597 1.61935604]
# [3.716341   5.89839191 7.8608011  5.89925489 3.34967421]

# %%
plt.scatter(X_1_pos, X_2_pos, color='red', marker='x')
plt.scatter(X_1_neg, X_2_neg, color='blue', marker='x')

# %%
X = np.block([[X_1_pos, X_2_pos], [X_1_neg, X_2_neg]])

# %%
X.shape
# Out:
# (40, 2)

# %%
X[0:5]
# Out:
# array([[6.35716091, 5.4790643 ],
#        [2.99187883, 5.3444234 ],
#        [5.92737474, 3.43664678],
#        [1.25017975, 6.93627909],
#        [1.64594008, 3.70299568]])

# %%
y = np.vstack((np.ones((20,1)), np.zeros((20,1)))).reshape(40,)

# %%
y[0:5]
# Out:
# array([1., 1., 1., 1., 1.])

# %%
y[-5:]
# Out:
# array([0., 0., 0., 0., 0.])

# %%
from sklearn.linear_model import LogisticRegression

# %%
example_lr = LogisticRegression(solver='liblinear')

# %%
example_lr
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='liblinear',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
example_lr.fit(X, y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='liblinear',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred = example_lr.predict(X)

# %%
#Short example of what a list comprehension is, next one mixes in if/else

# %%
prediction_colors = ['red' if prediction==1 else 'blue' for prediction in y_pred]
# prediction_colors

# %%
plt.scatter(X_1_pos, X_2_pos, color='red', marker='x')
plt.scatter(X_1_neg, X_2_neg, color='blue', marker='x')
plt.scatter(X[:,0], X[:,1], s=150, marker='o',
            edgecolors=prediction_colors, facecolors='none')

# %%
example_lr.coef_
# Out:
# array([[-0.20245058, -0.25336424]])

# %%
theta_1 = example_lr.coef_[0][0]
theta_2 = example_lr.coef_[0][1]

# %%
example_lr.intercept_
# Out:
# array([2.25479161])

# %%
theta_0 = example_lr.intercept_

# %% [markdown]
# $\theta_0 + \theta_1 X_1 + \theta_2 X_2 = 0$ is the equation for the decision boundary line, for a threshold of 0.5. Solving for "$y = mx + b$" form,

# %% [markdown]
# $X_2 = -\frac{\theta_1}{\theta_2}X_1 - \frac{\theta_0}{\theta_2}$

# %%
X_1_decision_boundary = np.array([0, 10])

# %%
X_2_decision_boundary = -(theta_1/theta_2)*X_1_decision_boundary - (theta_0/theta_2)

# %%
plt.scatter(X_1_pos, X_2_pos, color='red', marker='x')
plt.scatter(X_1_neg, X_2_neg, color='blue', marker='x')
plt.scatter(X[:,0], X[:,1], s=150, marker='o',
            edgecolors=prediction_colors, facecolors='none')
plt.plot(X_1_decision_boundary, X_2_decision_boundary, 'k-')
